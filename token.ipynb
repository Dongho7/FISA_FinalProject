# %%
import os
import requests
from dotenv import load_dotenv
# .env 파일 로드
load_dotenv()
APP_KEY = os.getenv("KIS_APP_KEY")
APP_SECRET = os.getenv("KIS_APP_SECRET")
BASE_URL = os.getenv("KIS_BASE_URL")
# :작은_파란색_다이아몬드: 접근 토큰 발급
def get_access_token():
    url = f"{BASE_URL}/oauth2/tokenP"
    headers = {"content-type": "application/json"}
    data = {
        "grant_type": "client_credentials",
        "appkey": APP_KEY,
        "appsecret": APP_SECRET
    }
    res = requests.post(url, json=data)
    res.raise_for_status()
    return res.json()["access_token"]
# :작은_파란색_다이아몬드: 특정 종목 현재가 조회 (예: 삼성전자 005930)

if __name__ == "__main__":
    token = get_access_token()
    print(token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImY5ZGJjNWZkLTlkYTYtNDA1YS04NDkzLTA5MzNkYTQ0OTNmOCIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc2MjU3ODQwNSwiaWF0IjoxNzYyNDkyMDA1LCJqdGkiOiJQUzh3MFFWMHpxdTNCR3k2ekZsTWlmV0Z4UjZXTk1RV2lHVkcifQ.lX6D23DYOtai_ef95Th4zn-PQ3nIT9IqiBlStMbo9b_LUW3PCbMdRTse21NgxvCQBL5qii3vXZsf9b5zvb4UuA

# %%
print(token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6ImJiMTIxN2ZiLTllYjYtNDkzMy1hNDdkLTBkN2MzNmRiOThiZiIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTc2MjIyODExNywiaWF0IjoxNzYyMTQxNzE3LCJqdGkiOiJQUzh3MFFWMHpxdTNCR3k2ekZsTWlmV0Z4UjZXTk1RV2lHVkcifQ.KLjLgf9PTSCoP9K0_ZPp2SIOV_XB1mBbVFDzG_rBVNgcrfi1WNOLcEDDQhxoL08W_YYsZ2BC5uPIZ3SAUAdu4w
